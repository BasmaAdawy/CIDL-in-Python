# %% [markdown]
# #**Linear Regression using Gradient Descent**
#
# ### This notebook demonstrates linear regression by minimizing the Mean Squared Error (MSE) loss using gradient descent. We will:
#  1. Generate a synthetic 2D dataset with noise
#  2. Implement gradient descent optimization
#  3. Visualize the results and loss curve
#  4. Plot the regression plane

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
np.random.seed(42)

# %% [markdown]
# # **Dataset Generation**
# ### We create a synthetic dataset with:
#  - 1000 samples (`P`)
#  - 2 input features (`X`)
#  - Linear relationship with predefined coefficients (`true_e`)
#  - Gaussian noise added to outputs

# %%
# Dataset parameters
P = 1000               # Number of samples
noise_level = 2        # Standard deviation of noise
offset = 2             # Shift input features
true_e = np.array([-4, 3, -7])

# Generate input features (P x 2 matrix)
X = np.random.randn(P, 2) + offset

# Create design matrix with bias term (add column of ones)
U = np.column_stack((np.ones(P), X))

# Generate target values with added noise
y = U @ true_e + noise_level * np.random.randn(P)

print("True coefficients:")
print(true_e)
# Out:
# True coefficients:
# [-4  3 -7]

# %% [markdown]
# # **Data Visualization**
#
#  3D scatter plot showing the original data distribution

# %%
import plotly.graph_objects as go

# Create 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=X[:, 0],
    y=X[:, 1],
    z=y,
    mode='markers',
    marker=dict(size=5, opacity=0.6)
)])

# Update layout
fig.update_layout(
    title='Original Data Distribution (Interactive)',
    scene=dict(
        xaxis_title='X1',
        yaxis_title='X2',
        zaxis_title='y'
    ),
    width=800,
    height=700
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f10af0d3-a637-4cb9-8b6f-2f932411782e" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f10af0d3-a637-4cb9-8b6f-2f932411782e")) {                    Plotly.newPlot(                        "f10af0d3-a637-4cb9-8b6f-2f932411782e",                        [{"marker":{"opacity":0.6,"size":5},"mode":"markers","x":[2.496714153011233,2.6476885381006925,1.765846625276664,3.5792128155073915,1.5305256140650478,1.5365823071875377,2.241962271566034,0.27508216748696723,0.9871688796655762,1.0919759244787892,3.465648768921554,2.0675282046879238,1.4556172754748173,0.8490064225776972,1.399361310081195,1.398293387770603,1.986502775262066,2.822544912103189,2.2088635950047553,0.6718139511015695,2.7384665799954107,1.8843517176117595,0.5214780096325726,1.5393612290402126,2.3436182895684614,2.324083969394795,1.3230779996940414,3.030999522495951,1.1607824767773613,2.331263431403564,1.52082576215471,0.8936650259939718,2.812525822394198,1.927989878419666,2.361636025047634,2.361395605508414,1.9641739608900484,-0.6197451040897444,2.087047068238171,2.0917607765355024,1.780328112162488,3.4778940447415163,1.1915063971068123,2.915402117702074,1.4702397962329612,2.0970775493480405,1.2979469061226476,1.6078918468678425,2.296120277064576,2.005113456642461,0.5846292579495858,1.6572854834732305,1.8387142883339909,3.8861859012105304,2.2575503907227645,0.08122878470095851,2.0602302099410266,1.8076390352188776,1.9652882302947567,3.1428228145150205,2.791031947043047,3.402794310936099,2.5868570938002704,1.0094636748693118,2.099651365087641,0.4493365689338673,0.9376962862738951,1.0805757657661967,1.2167467076637628,2.81351721736967,2.2274599346041293,0.39251676543877245,2.2598827942484236,0.763049289121918,2.5219415656168978,2.2504928503458768,1.3199752784215093,2.293072473298681,3.865774511144757,0.8086965027973514,1.0253183297726784,3.158595579007404,2.9633761292443217,2.82206015999449,1.7546118839971294,1.1104855703744767,1.9228982905858958,2.276690799330019,2.013001891877907,1.735343166762044,2.625667347765006,0.9291075019388877,1.7765372146741492,2.473237624573545,1.153206281931595,1.553485047932979,2.2140937441302038,2.173180925851182,1.1161425637988671,2.058208718446,2.3577873603482833,3.083051243175277,0.622330632042909,2.5150352672086598,2.515047686306048,2.570890510693167,2.9540017634932023,1.6847307553596544,1.2271747854624282,1.5146364521708966,4.314658566673509,2.6862601903745134,1.5280681342105664,2.0642800190954627,1.2846962907400319,1.2696333682828633,2.045571839903814,4.143944089325325,-0.025142586657607158,1.338213535231612,1.2074792615672993,2.5049872789804573,0.7997035929442238,1.525054688839044,3.765454240281097,0.7391160456649548,4.122156197012633,0.4806300340459866,3.2669111491866225,2.443819428146228,1.0730695284219172,-1.2412673400690726,1.7474318486068396,3.6324113039316352,1.5599555133030163,3.4412732890661157,3.1631637521549596,1.018491348952049,2.19905969557347,2.0698020849900187,2.113517345251248,3.586016816145352,4.133033374656266,1.8482149049644168,2.2809918677350325,1.7918777496427247,1.4106352430557885,2.3570154859650474,2.8995998754332506,2.81286211883896,1.1710049890779277,2.7472936051232617,1.9790984060358519,3.277664895788425,2.5470973811700377,1.7823187967727798,2.8254163489880297,3.305478807154329,2.681952971294964,2.324166352488442,2.0969959649927183,1.1817793167665274,0.993982618500298,3.1581108735000676,2.624119817052155,1.9877532271530853,2.0758045581937266,2.9751197334177513,1.1745028032074885,2.412931454275624,1.1777796044335687,2.2449665711087228,1.5289616943816773,0.5519156585026759,1.281555778747564,2.3109075655980047,2.8576596232020193,1.9809837920973112,1.98148686400761,2.3227185603380893,2.5193465142411724,1.8912 ...

# %% [markdown]
# # **Gradient Descent Implementation**
#
# ## Key components:
#  - **MSE Loss**: $J(\mathbf{e}) = \frac{1}{2N} \sum_{i=1}^N (\hat{y}^{(i)} - y^{(i)})^2$
#  - **Gradient**: $\nabla J = \frac{1}{N} \mathbf{U}^T (\mathbf{\hat{y}} - \mathbf{y})$
#  - **Update Rule**: $\mathbf{e} \leftarrow \mathbf{e} - \eta \nabla J$

# %%
def lin_regr_assuming_MSE_and_using_GD(U, y, eta, iterations):
    """
    Performs linear regression using gradient descent to minimize MSE loss.

    Parameters:
    U : ndarray (N x D+1)
        Design matrix with bias term
    y : ndarray (N,)
        Target values
    eta : float
        Learning rate
    iterations : int
        Number of gradient descent iterations

    Returns:
    e : ndarray (D+1,)
        Optimized coefficient vector [bias, w1, ..., wD]
    MSE_loss : ndarray (iterations,)
        Loss values during training
    """
    N = U.shape[0]          # Number of samples
    e = np.zeros(U.shape[1]) # Initialize coefficients
    MSE_loss = np.zeros(iterations)

    for j in range(iterations):
        # Compute predictions
        y_pred = U @ e

        # Calculate MSE loss
        MSE_loss[j] = np.sum((y_pred - y)**2) / (2 * N)

        # Compute gradient
        gradient = U.T @ (y_pred - y) / N

        # Update coefficients
        e -= eta * gradient

    return e, MSE_loss

# %% [markdown]
# # **Model Training**
# ## Hyperparameters:
# - Learning rate (`eta`): 0.1
# - Iterations: 1000

# %%
# Training parameters
eta = 0.1
iterations = 1000

# Train model
e, MSE_loss = lin_regr_assuming_MSE_and_using_GD(U, y, eta, iterations)

# Display results
print("\nFitted coefficients:")
print(e)
# Out:
# Fitted coefficients:
# [-4.17158399  3.0554834  -6.96574352]

# %% [markdown]
# # **Results Visualization**
#
# ## 1. Loss Curve
# Shows MSE reduction during training

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, iterations+1), MSE_loss)
plt.xlabel('Iteration')
plt.ylabel('MSE Loss')
plt.title('Loss Convergence During Training')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Data vs. Predictions
#  Compares original data with model predictions

# %%
import plotly.graph_objects as go

# Create 3D scatter plot
fig = go.Figure()

# Original data
fig.add_trace(go.Scatter3d(
    x=X[:, 0], y=X[:, 1], z=y,
    mode='markers',
    marker=dict(size=5, opacity=0.6),
    name='Original Data'
))

# Calculate predictions using the trained coefficients 'e'
y_pred = U @ e

# Model predictions
fig.add_trace(go.Scatter3d(
    x=X[:, 0], y=X[:, 1], z=y_pred,
    mode='markers',
    marker=dict(size=5, opacity=0.6, color='red'),
    name='Predictions'
))

# Update layout
fig.update_layout(
    title='Data vs. Model Predictions (Interactive)',
    scene=dict(
        xaxis_title='X1',
        yaxis_title='X2',
        zaxis_title='y'
    ),
    width=800,
    height=700,
    legend=dict(x=0.7, y=0.9)  # Adjust legend position
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b5effb8d-3fd3-4773-8b1f-d02f0533aae6" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5effb8d-3fd3-4773-8b1f-d02f0533aae6")) {                    Plotly.newPlot(                        "b5effb8d-3fd3-4773-8b1f-d02f0533aae6",                        [{"marker":{"opacity":0.6,"size":5},"mode":"markers","name":"Original Data","x":[2.496714153011233,2.6476885381006925,1.765846625276664,3.5792128155073915,1.5305256140650478,1.5365823071875377,2.241962271566034,0.27508216748696723,0.9871688796655762,1.0919759244787892,3.465648768921554,2.0675282046879238,1.4556172754748173,0.8490064225776972,1.399361310081195,1.398293387770603,1.986502775262066,2.822544912103189,2.2088635950047553,0.6718139511015695,2.7384665799954107,1.8843517176117595,0.5214780096325726,1.5393612290402126,2.3436182895684614,2.324083969394795,1.3230779996940414,3.030999522495951,1.1607824767773613,2.331263431403564,1.52082576215471,0.8936650259939718,2.812525822394198,1.927989878419666,2.361636025047634,2.361395605508414,1.9641739608900484,-0.6197451040897444,2.087047068238171,2.0917607765355024,1.780328112162488,3.4778940447415163,1.1915063971068123,2.915402117702074,1.4702397962329612,2.0970775493480405,1.2979469061226476,1.6078918468678425,2.296120277064576,2.005113456642461,0.5846292579495858,1.6572854834732305,1.8387142883339909,3.8861859012105304,2.2575503907227645,0.08122878470095851,2.0602302099410266,1.8076390352188776,1.9652882302947567,3.1428228145150205,2.791031947043047,3.402794310936099,2.5868570938002704,1.0094636748693118,2.099651365087641,0.4493365689338673,0.9376962862738951,1.0805757657661967,1.2167467076637628,2.81351721736967,2.2274599346041293,0.39251676543877245,2.2598827942484236,0.763049289121918,2.5219415656168978,2.2504928503458768,1.3199752784215093,2.293072473298681,3.865774511144757,0.8086965027973514,1.0253183297726784,3.158595579007404,2.9633761292443217,2.82206015999449,1.7546118839971294,1.1104855703744767,1.9228982905858958,2.276690799330019,2.013001891877907,1.735343166762044,2.625667347765006,0.9291075019388877,1.7765372146741492,2.473237624573545,1.153206281931595,1.553485047932979,2.2140937441302038,2.173180925851182,1.1161425637988671,2.058208718446,2.3577873603482833,3.083051243175277,0.622330632042909,2.5150352672086598,2.515047686306048,2.570890510693167,2.9540017634932023,1.6847307553596544,1.2271747854624282,1.5146364521708966,4.314658566673509,2.6862601903745134,1.5280681342105664,2.0642800190954627,1.2846962907400319,1.2696333682828633,2.045571839903814,4.143944089325325,-0.025142586657607158,1.338213535231612,1.2074792615672993,2.5049872789804573,0.7997035929442238,1.525054688839044,3.765454240281097,0.7391160456649548,4.122156197012633,0.4806300340459866,3.2669111491866225,2.443819428146228,1.0730695284219172,-1.2412673400690726,1.7474318486068396,3.6324113039316352,1.5599555133030163,3.4412732890661157,3.1631637521549596,1.018491348952049,2.19905969557347,2.0698020849900187,2.113517345251248,3.586016816145352,4.133033374656266,1.8482149049644168,2.2809918677350325,1.7918777496427247,1.4106352430557885,2.3570154859650474,2.8995998754332506,2.81286211883896,1.1710049890779277,2.7472936051232617,1.9790984060358519,3.277664895788425,2.5470973811700377,1.7823187967727798,2.8254163489880297,3.305478807154329,2.681952971294964,2.324166352488442,2.0969959649927183,1.1817793167665274,0.993982618500298,3.1581108735000676,2.624119817052155,1.9877532271530853,2.0758045581937266,2.9751197334177513,1.1745028032074885,2.412931454275624,1.1777796044335687,2.2449665711087228,1.5289616943816773,0.5519156585026759,1.281555778747564,2.3109075655980047,2.8576596232020193,1.9809837920973112,1.98148686400761,2.3227185603380893,2. ...

# %% [markdown]
# ## 3. Regression Plane
# Visualizes the learned linear decision boundary

# %%
import plotly.graph_objects as go

# Create a grid of points for the regression plane
x1_range = np.linspace(X[:, 0].min(), X[:, 0].max(), 50)
x2_range = np.linspace(X[:, 1].min(), X[:, 1].max(), 50)
x1_grid, x2_grid = np.meshgrid(x1_range, x2_range)

# Calculate the corresponding z values using the fitted coefficients 'e'
# The equation of the plane is z = e[0] + e[1]*x1 + e[2]*x2
z_grid = e[0] + e[1] * x1_grid + e[2] * x2_grid

# Create figure
fig = go.Figure()

# Add regression plane surface
fig.add_trace(go.Surface(
    x=x1_grid,
    y=x2_grid,
    z=z_grid,
    colorscale='Viridis',
    opacity=0.5,
    showscale=False,
    name='Regression Plane'
))

# Add original data points
fig.add_trace(go.Scatter3d(
    x=X[:, 0],
    y=X[:, 1],
    z=y,
    mode='markers',
    marker=dict(
        size=3,
        opacity=0.2,
        color='black'
    ),
    name='Original Data'
))

# Update layout
fig.update_layout(
    title='Regression Plane (Interactive)',
    scene=dict(
        xaxis_title='X1',
        yaxis_title='X2',
        zaxis_title='y'
    ),
    width=800,
    height=700,
    margin=dict(l=0, r=0, b=0, t=30)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="82e3fead-6a89-4feb-aa0f-117d87c9aeb4" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82